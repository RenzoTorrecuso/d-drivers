# %% [markdown]
# # Notebook for labeling Articles with ranking of related google searches (extracted from google trends)
#
# 1. Test-run with sample data
# 2. Interpretation of test-run
# 3. Classification and export for feature candidates

# %%
from transformers import pipeline
import pandas as pd
from tqdm import tqdm

# %%
classifier = pipeline("zero-shot-classification", model="joeddav/xlm-roberta-large-xnli")
# Out:
# All model checkpoint layers were used when initializing TFXLMRobertaForSequenceClassification.
#
# All the layers of TFXLMRobertaForSequenceClassification were initialized from the model checkpoint at joeddav/xlm-roberta-large-xnli.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFXLMRobertaForSequenceClassification for predictions without further training.

# %% [markdown]
# ## 1. Testrun with sample
# - get one example ('E-Auto') from page_ids in feature data set and apply the classifier model with lables from google trends realated queries for 'E-Auto'

# %%
file_path_features = '../data/data_features.csv'
file_path_labels = '../data/related_queries.csv'

df = pd.read_csv(file_path_features)
df_labels = pd.read_csv(file_path_labels)

# %%
df_labels.info()

# %%
df_labels.head(20)

# %%
# get sample text to be classified from classification_product = 'E-Auto'

df_e_auto = df[df['classification_product'] == 'E-Auto']

sample_abstract = df_e_auto.abstract.iloc[0]
sample_meta_desc = df_e_auto.meta_description.iloc[0]
sample_meta_title = df_e_auto.meta_title.iloc[0]

# %%
# get labels for classification from google trends related searches for search term = 'E-Auto'
df_labels_e_auto = df_labels[df_labels['classification_product'] == 'E-Auto']

labels_e_auto = df_labels_e_auto['query'].astype(str).tolist()

# %%
df_labels_e_auto['query']

# %%
def get_predictions_score_tab(prediction):
    """
    Function to display predictions from the model in a tabular form
    """
    pred_labels = prediction['labels']
    pred_scores = prediction['scores']
    seq = [prediction['sequence']]
    return  pd.concat([
                pd.DataFrame(seq),
                pd.DataFrame(pred_labels),
                pd.DataFrame(pred_scores),
            ], axis=1, ignore_index=True).rename(columns={0:'Sequence',1:'Labels', 2:'Probability'}).set_index(['Sequence'])

# %%
sequence1 = sample_abstract
sequence2 = sample_meta_desc
sequence3 = sample_meta_title
sequence_concat = ' '.join([sequence1, sequence2, sequence3])

# %%
candidate_labels = labels_e_auto # ["geography",  "delivery"]

# %%
pred1 = classifier(sequence1, candidate_labels)
pred2 = classifier(sequence2, candidate_labels)
pred3 = classifier(sequence3, candidate_labels)

# %%
pred4 = classifier(sequence_concat, candidate_labels)

# %%
get_predictions_score_tab(pred1)
# Out:
#                                                                    Labels
# Sequence
# Im Grunde kann man sein E-Auto überall laden, w...            elektroauto  \
# NaN                                                                e auto
# NaN                                                          e-auto laden
# NaN                                                          e auto laden
# NaN                                                      förderung e-auto
# NaN                                                         e-auto kaufen
# NaN                                                      e-auto vergleich
# NaN                                                     e-auto reichweite
# NaN                                                     e-auto kleinwagen
# NaN                                                    e-auto ladestation
# NaN                                                         e-auto prämie
# NaN                                                 förderung e-auto 2023
# NaN                                                        leasing e auto
# NaN                                                          auto leasing
# NaN                                                      e-auto gebraucht
# NaN                                                               wallbox
# NaN                                                             vw e-auto
# NaN                                                           opel e-auto
# NaN                                                            bmw e-auto
# NaN                                                        leasing e-auto
# NaN                                                          skoda e-auto
# NaN                                                                    vw
# NaN                                                                  opel
# NaN                                                                 tesla
# NaN                                                                 skoda
#
#                                                     Probability
# Sequence
# Im Grunde kann man sein E-Auto überall laden, w...     0.554633
# NaN                                                    0.220633
# NaN                                                    0.074661
# NaN                                                    0.046809
# NaN                                                    0.017415
# NaN                                                    0.013685
# NaN                                                    0.013080
# NaN                                                    0.009276
# NaN                                                    0.006359
# NaN                                                    0.004870
# NaN                                                    0.004752
# NaN                                                    0.003632
# NaN                                                    0.003447
# NaN                                                    0.003219
# NaN                                                    0.003059
# NaN                                                    0.002330
# NaN                                                    0.002318
# NaN                                                    0.002241
# NaN                                                    0.002153
# NaN                                                    0.002063
# NaN                                                    0.002002
# NaN                                                    0.001888
# NaN                                                    0.001849
# NaN                                                    0.001848
# NaN                                                    0.001778

# %% [markdown]
# ### Label and score result for *Abstract*: 'elektroauto' --> googel related query score (34)

# %%
get_predictions_score_tab(pred2)
# Out:
#                                                                    Labels
# Sequence
# Ladestationen für Elektroautos. Kosten und Anbi...       e-auto vergleich  \
# NaN                                                          e-auto laden
# NaN                                                    e-auto ladestation
# NaN                                                           elektroauto
# NaN                                                          e auto laden
# NaN                                                      förderung e-auto
# NaN                                                         e-auto kaufen
# NaN                                                         e-auto prämie
# NaN                                                     e-auto reichweite
# NaN                                                                e auto
# NaN                                                     e-auto kleinwagen
# NaN                                                          auto leasing
# NaN                                                           opel e-auto
# NaN                                                               wallbox
# NaN                                                        leasing e-auto
# NaN                                                             vw e-auto
# NaN                                                 förderung e-auto 2023
# NaN                                                          skoda e-auto
# NaN                                                      e-auto gebraucht
# NaN                                                            bmw e-auto
# NaN                                                                    vw
# NaN                                                                  opel
# NaN                                                                 skoda
# NaN                                                                 tesla
# NaN                                                        leasing e auto
#
#                                                     Probability
# Sequence
# Ladestationen für Elektroautos. Kosten und Anbi...     0.376705
# NaN                                                    0.204149
# NaN                                                    0.177800
# NaN                                                    0.096548
# NaN                                                    0.081190
# NaN                                                    0.024533
# NaN                                                    0.007046
# NaN                                                    0.006781
# NaN                                                    0.003179
# NaN                                                    0.003076
# NaN                                                    0.002808
# NaN                                                    0.001568
# NaN                                                    0.001527
# NaN                                                    0.001512
# NaN                                                    0.001471
# NaN                                                    0.001411
# NaN                                                    0.001352
# NaN                                                    0.001088
# NaN                                                    0.001028
# NaN                                                    0.001015
# NaN                                                    0.000962
# NaN                                                    0.000952
# NaN                                                    0.000797
# NaN                                                    0.000772
# NaN                                                    0.000728

# %% [markdown]
# ### Label and score result for *Meta Description*: 'e-auto vergleich' (15)

# %%
get_predictions_score_tab(pred3)
# Out:
#                                                                    Labels
# Sequence
# Elektrofahrzeug-Ladestation: Anbieter, Kosten, ...     e-auto ladestation  \
# NaN                                                      e-auto vergleich
# NaN                                                          e-auto laden
# NaN                                                      förderung e-auto
# NaN                                                           elektroauto
# NaN                                                          e auto laden
# NaN                                                         e-auto prämie
# NaN                                                     e-auto reichweite
# NaN                                                     e-auto kleinwagen
# NaN                                                         e-auto kaufen
# NaN                                                           opel e-auto
# NaN                                                               wallbox
# NaN                                                                    vw
# NaN                                                             vw e-auto
# NaN                                                 förderung e-auto 2023
# NaN                                                                  opel
# NaN                                                                 tesla
# NaN                                                          skoda e-auto
# NaN                                                            bmw e-auto
# NaN                                                                 skoda
# NaN                                                          auto leasing
# NaN                                                      e-auto gebraucht
# NaN                                                        leasing e auto
# NaN                                                                e auto
# NaN                                                        leasing e-auto
#
#                                                     Probability
# Sequence
# Elektrofahrzeug-Ladestation: Anbieter, Kosten, ...     0.295233
# NaN                                                    0.186813
# NaN                                                    0.165971
# NaN                                                    0.126846
# NaN                                                    0.076566
# NaN                                                    0.044460
# NaN                                                    0.039827
# NaN                                                    0.011048
# NaN                                                    0.009537
# NaN                                                    0.004864
# NaN                                                    0.004112
# NaN                                                    0.003579
# NaN                                                    0.003267
# NaN                                                    0.003265
# NaN                                                    0.003013
# NaN                                                    0.002951
# NaN                                                    0.002603
# NaN                                                    0.002580
# NaN                                                    0.002534
# NaN                                                    0.002471
# NaN                                                    0.002262
# NaN                                                    0.001945
# NaN                                                    0.001448
# NaN                                                    0.001406
# NaN                                                    0.001398

# %% [markdown]
# ### Label and score result for *Meta Title*: 'e-auto ladestation' (27)

# %%
get_predictions_score_tab(pred4)
# Out:
#                                                                    Labels
# Sequence
# Im Grunde kann man sein E-Auto überall laden, w...       e-auto vergleich  \
# NaN                                                          e-auto laden
# NaN                                                           elektroauto
# NaN                                                    e-auto ladestation
# NaN                                                          e auto laden
# NaN                                                                e auto
# NaN                                                      förderung e-auto
# NaN                                                     e-auto reichweite
# NaN                                                         e-auto prämie
# NaN                                                         e-auto kaufen
# NaN                                                     e-auto kleinwagen
# NaN                                                      e-auto gebraucht
# NaN                                                 förderung e-auto 2023
# NaN                                                               wallbox
# NaN                                                             vw e-auto
# NaN                                                           opel e-auto
# NaN                                                                    vw
# NaN                                                                  opel
# NaN                                                          skoda e-auto
# NaN                                                                 tesla
# NaN                                                            bmw e-auto
# NaN                                                                 skoda
# NaN                                                          auto leasing
# NaN                                                        leasing e-auto
# NaN                                                        leasing e auto
#
#                                                     Probability
# Sequence
# Im Grunde kann man sein E-Auto überall laden, w...     0.534223
# NaN                                                    0.122227
# NaN                                                    0.118224
# NaN                                                    0.070181
# NaN                                                    0.041920
# NaN                                                    0.030883
# NaN                                                    0.015133
# NaN                                                    0.011212
# NaN                                                    0.011115
# NaN                                                    0.007534
# NaN                                                    0.004657
# NaN                                                    0.003604
# NaN                                                    0.003274
# NaN                                                    0.003064
# NaN                                                    0.002810
# NaN                                                    0.002782
# NaN                                                    0.002762
# NaN                                                    0.002405
# NaN                                                    0.002320
# NaN                                                    0.002288
# NaN                                                    0.002240
# NaN                                                    0.002139
# NaN                                                    0.001166
# NaN                                                    0.000933
# NaN                                                    0.000901

# %% [markdown]
# ### Label and score result for *Abstract + Meta description + Meta Title*: 'e-auto vergleich' (15)

# %% [markdown]
# ## 2. Testrun Conclusion:
# labeling by abstract, meta_title and meta_description lead to different results in Propability and Score:
# Input / Propability / Score
# - Abstract /  55% / 34
# - Metra Description / 38% / 15
# - Meta Title / 29% / 27
# - All together / 53% / 15
#
# --> **Outlook / Improvements**: try out multi labelling and hypothesis templates

# %% [markdown]
# ## 3. Enrich page_ids with google score

# %%
# Define the function get_predictions_score
def get_predictions_score(prediction):
    pred_labels = prediction['labels']
    pred_scores = prediction['scores']
    
    # Find the index of the label with the highest probability
    max_index = pred_scores.index(max(pred_scores))
    
    # Extract the label and its corresponding probability
    max_label = pred_labels[max_index]
    max_probability = pred_scores[max_index]
    
    return max_label, max_probability

# %%
get_predictions_score(pred4)
# Out:
# ('e-auto vergleich', 0.5342233777046204)

# %% [markdown]
# ### start with 'Versicherung' (only 16 records)

# %%
# classification per entity of classification_product
class_product = df.classification_product.unique().tolist()
class_product
# Out:
# ['E-Auto',
#  'Auto',
#  'Zubehör',
#  'Motorrad',
#  'Energie',
#  'Verkehr',
#  'Wallbox/Laden',
#  'Solaranlagen',
#  'E-Bike',
#  'Fahrrad',
#  'E-Scooter',
#  'Solarspeicher',
#  'Balkonkraftwerk',
#  'Solargenerator',
#  'THG',
#  'Wärmepumpe',
#  'Versicherung']

# %%
relevant_columns = ['page_id', 'classification_product', 'abstract', 'meta_description', 'meta_title' ]
df_gscore = df[relevant_columns].copy()
df_gscore['text_to_classify'] = df_gscore['abstract'] + ' ' + df_gscore['meta_description'] + ' ' + df_gscore['meta_title']


df_gscore_out = pd.DataFrame(columns=relevant_columns + ['text_to_classify', 'predicted_query_label', 'predicted_probability'])

df_gscore.shape

# %%
filter = 'Versicherung'

# %%
iter = filter

df_labels_per_category = df_labels[df_labels['classification_product'] == iter]
candidate_labels = df_labels_per_category['query'].astype(str).tolist()

df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]

tqdm.pandas(desc=f"Googel search related keyword classification for {iter}")
df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))

df_gscore_iter

# %%
df_gscore_iter.to_csv('../data/google_trends/data_trends_class_versicherung.csv')

# %% [markdown]
# ### Solargenerator does not exist

# %% [markdown]
# ### Solarspeicher

# %%
filter = 'Solarspeicher'

# %%
iter = filter

df_labels_per_category = df_labels[df_labels['classification_product'] == iter]
candidate_labels = df_labels_per_category['query'].astype(str).tolist()

df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]

tqdm.pandas(desc=f"Googel search related keyword classification for {iter}")
df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))

df_gscore_iter
# Out:
# Googel search related keyword classification for Solarspeicher: 100%|██████████| 80/80 [1:34:22<00:00, 70.79s/it]
# /var/folders/yg/ktnhtx296n9c7dtx07yzyrt00000gn/T/ipykernel_9557/74430780.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))
# /var/folders/yg/ktnhtx296n9c7dtx07yzyrt00000gn/T/ipykernel_9557/74430780.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))
#       page_id classification_product
# 103    104438          Solarspeicher  \
# 284    107520          Solarspeicher
# 296    107679          Solarspeicher
# 739   1010660          Solarspeicher
# 1109  1011212          Solarspeicher
# ...       ...                    ...
# 6011  1017508          Solarspeicher
# 6191  1017790          Solarspeicher
# 6248  1017871          Solarspeicher
# 6794  1018741          Solarspeicher
# 6809  1018767          Solarspeicher
#
#                                                abstract
# 103   Betrachtet man sein E-Auto ein wenig anders, k...  \
# 284   Auch wenn das Design des portablen Riesenakkus...
# 296   Mittlerweile gibt es eine immer größer werdend...
# 739   Wenn Sie Ihre PV-Anlage mit einem Energiespeic...
# 1109  PV-Anlagen mit Speicher sorgen dafür, dass eig...
# ...                                                 ...
# 6011  Eine beeindruckende Entwicklung in Sachen Sola...
# 6191  In Deutschland markiert das vergangene Jahr ei...
# 6248  Umfassende Transparenz in der Branche der Heim...
# 6794  Eine neue Speicherlösung für das eigene Balkon...
# 6809  Schnäppchenjäger aufgepasst! Eine leistungssta...
#
#                                        meta_description
# 103   SEO Description ändern: E-Auto als Stromspeich...  \
# 284   Auch wenn das Design des portablen Riesenakkus...
# 296   Solarspeicher - Testsieger: Das sind die beste...
# 739   Wenn Sie Ihre PV-Anlage mit einem Energiespeic...
# 1109  PV-Anlagen mit Speicher sorgen dafür, dass eig...
# ...                                                 ...
# 6011  Eine beeindruckende Entwicklung in Sachen Sola...
# 6191  In Deutschland markiert das vergangene Jahr ei...
# 6248  Umfassende Transparenz in der Branche der Heim...
# 6794  Zur Markteinführung des VitaPower-Speichers ge...
# 6809  Amazon reduziert Bluetti AC180 Powerstation – ...
#
#                                              meta_title
# 103   Elektroauto als Stromspeicher nutzen: So funkt...  \
# 284   Batterie auf Rädern versorgt mühelos ein ganze...
# 296   Solarspeicher im Test 2023/24: Die besten Mode...
# 739   Energiespeicher bei Solaranlage: So lange hält...
# 1109    PV-Anlage mit Speicher: Preise, Anbieter, Infos
# ...                                                 ...
# 6011  Verdoppelung in nur einem Jahr: Deutsche insta...
# 6191  Meilenstein geknackt: Stromspeicher reichen je...
# 6248  Die besten Stromspeicher 2024: Deutsche Herste...
# 6794  Neuer Speicher für Balkonkraftwerke kommt: Frü...
# 6809  Amazon verscherbelt Powerstation: Angebot gilt...
#
#                                        text_to_classify
# 103   Betrachtet man sein E-Auto ein wenig anders, k...  \
# 284   Auch wenn das Design des portablen Riesenakkus...
# 296   Mittlerweile gibt es eine immer größer werdend...
# 739   Wenn Sie Ihre PV-Anlage mit einem Energiespeic...
# 1109  PV-Anlagen mit Speicher sorgen dafür, dass eig...
# ...                                                 ...
# 6011  Eine beeindruckende Entwicklung in Sachen Sola...
# 6191  In Deutschland markiert das vergangene Jahr ei...
# 6248  Umfassende Transparenz in der Branche der Heim...
# 6794  Eine neue Speicherlösung für das eigene Balkon...
# 6809  Schnäppchenjäger aufgepasst! Eine leistungssta...
#
#          predicted_query_label  predicted_probability
# 103              stromspeicher               0.650090
# 284              stromspeicher               0.416165
# 296               photovoltaik               0.340139
# 739             solar speicher               0.229040
# 1109               solaranlage               0.236906
# ...                        ...                    ...
# 6011            solar speicher               0.462494
# 6191            solar speicher               0.258887
# 6248             stromspeicher               0.711050
# 6794  balkonkraftwerk speicher               0.244425
# 6809                       byd               0.150790
#
# [80 rows x 8 columns]

# %%
df_gscore_iter.to_csv('../data/google_trends/data_trends_class_solarspeicher.csv')

# %% [markdown]
# ## E-Bike

# %%
def trends_classify(filter, df_labels=df_labels, df_gscore=df_gscore, classifier=classifier):
    iter = filter

    df_labels_per_category = df_labels[df_labels['classification_product'] == iter]
    candidate_labels = df_labels_per_category['query'].astype(str).tolist()

    df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]

    tqdm.pandas(desc=f"Googel search related keyword classification for {iter}")
    df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))

    return df_gscore_iter

# %%
filter = 'E-Bike'

# %%
trends_classify(filter)

# %%
# prepare dataset for processing
relevant_columns = ['page_id', 'classification_product', 'abstract', 'meta_description', 'meta_title' ]
df_gscore = df[relevant_columns].copy()
df_gscore['text_to_classify'] = df_gscore['abstract'] + ' ' + df_gscore['meta_description'] + ' ' + df_gscore['meta_title']


# classification per entity of classification_product
class_product = df.classification_product.unique().tolist()


df_gscore_out = pd.DataFrame(columns=relevant_columns + ['text_to_classify', 'predicted_query_label', 'predicted_probability'])

filter = 'Versicherung'

for iter in tqdm(class_product):
    if iter == filter:
        tqdm.pandas(desc=f"Googel search related keyword classification for {iter}")
        # get relevant candidate_labels
        df_labels_per_category = df_labels[df_labels['classification_product'] == iter]
        candidate_labels = df_labels_per_category['query'].astype(str).tolist()
        print(iter)
        print(labels_per_category)
        df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]

        df_gscore_iter['predicted_query_label'], df_gscore_iter['predicted_probability'] = zip(*df_gscore_iter['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))
        df_gscore_out = pd.concat(df_gscore_out, df_gscore_iter, ignore_index=True )
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
# Versicherung
# ['versicherung kfz', 'versicherung auto', 'allianz', 'allianz versicherung', 'ergo versicherung', 'huk', 'huk versicherung', 'ergo', 'adac versicherung', 'adac', 'vhv versicherung', 'check24 versicherung', 'axa versicherung', 'versicherung kündigen', 'lvm versicherung', 'württembergische versicherung', 'devk versicherung', 'devk', 'württembergische', 'kfz versicherung vergleich', 'wgv versicherung', 'hdi versicherung', 'wgv', 'nürnberger versicherung', 'hdi']
# Googel search related keyword classification for Versicherung:   0%|          | 5/6815 [04:16<96:54:08, 51.23s/it]
#  94%|█████████▍| 16/17 [04:16<00:16, 16.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 25
#      22 print(labels_per_category)
#      23 df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]
# ---> 25 df_gscore_iter['predicted_query_label'], df_gscore['predicted_probability'] = zip(*df_gscore['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))
#      26 df_gscore_out = pd.concat(df_gscore_out, df_gscore_iter, ignore_index=True )
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[85], line 25, in <lambda>(x)
#      22 print(labels_per_category)
#      23 df_gscore_iter = df_gscore[df_gscore['classification_product'] == iter]
# ---> 25 df_gscore_iter['predicted_query_label'], df_gscore['predicted_probability'] = zip(*df_gscore['text_to_classify'].progress_apply(lambda x: get_predictions_score(classifier(x, candidate_labels))))
#      26 df_gscore_out = pd.concat(df_gscore_out, df_gscore_iter, ignore_index=True )
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/pipelines/zero_shot_classification.py:206, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     203 else:
#     204     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 206 return super().__call__(sequences, **kwargs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/pipelines/base.py:1206, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1198     return next(
#    1199         iter(
#    1200             self.get_iterator(
#    (...)
#    1203         )
#    1204     )
#    1205 else:
# -> 1206     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/pipelines/base.py:1228, in ChunkPipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1226 all_outputs = []
#    1227 for model_inputs in self.preprocess(inputs, **preprocess_params):
# -> 1228     model_outputs = self.forward(model_inputs, **forward_params)
#    1229     all_outputs.append(model_outputs)
#    1230 outputs = self.postprocess(all_outputs, **postprocess_params)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/pipelines/base.py:1107, in Pipeline.forward(self, model_inputs, **forward_params)
#    1105 if self.framework == "tf":
#    1106     model_inputs["training"] = False
# -> 1107     model_outputs = self._forward(model_inputs, **forward_params)
#    1108 elif self.framework == "pt":
#    1109     inference_context = self.get_inference_context()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/pipelines/zero_shot_classification.py:229, in ZeroShotClassificationPipeline._forward(self, inputs)
#     227 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     228     model_inputs["use_cache"] = False
# --> 229 outputs = self.model(**model_inputs)
#     231 model_outputs = {
#     232     "candidate_label": candidate_label,
#     233     "sequence": sequence,
#     234     "is_last": inputs["is_last"],
#     235     **outputs,
#     236 }
#     237 return model_outputs
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:437, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     434     config = self.config
#     436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437 return func(self, **unpacked_inputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:1444, in TFXLMRobertaForSequenceClassification.call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training)
#    1415 @unpack_inputs
#    1416 @add_start_docstrings_to_model_forward(XLM_ROBERTA_INPUTS_DOCSTRING.format("batch_size, sequence_length"))
#    1417 @add_code_sample_docstrings(
#    (...)
#    1436     training: Optional[bool] = False,
#    1437 ) -> Union[TFSequenceClassifierOutput, Tuple[tf.Tensor]]:
#    1438     r"""
#    1439     labels (`tf.Tensor` of shape `(batch_size,)`, *optional*):
#    1440         Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1441         config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1442         `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1443     """
# -> 1444     outputs = self.roberta(
#    1445         input_ids,
#    1446         attention_mask=attention_mask,
#    1447         token_type_ids=token_type_ids,
#    1448         position_ids=position_ids,
#    1449         head_mask=head_mask,
#    1450         inputs_embeds=inputs_embeds,
#    1451         output_attentions=output_attentions,
#    1452         output_hidden_states=output_hidden_states,
#    1453         return_dict=return_dict,
#    1454         training=training,
#    1455     )
#    1456     sequence_output = outputs[0]
#    1457     logits = self.classifier(sequence_output, training=training)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/modeling_tf_utils.py:437, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     434     config = self.config
#     436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437 return func(self, **unpacked_inputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:926, in TFXLMRobertaMainLayer.call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     923 else:
#     924     head_mask = [None] * self.config.num_hidden_layers
# --> 926 encoder_outputs = self.encoder(
#     927     hidden_states=embedding_output,
#     928     attention_mask=extended_attention_mask,
#     929     head_mask=head_mask,
#     930     encoder_hidden_states=encoder_hidden_states,
#     931     encoder_attention_mask=encoder_extended_attention_mask,
#     932     past_key_values=past_key_values,
#     933     use_cache=use_cache,
#     934     output_attentions=output_attentions,
#     935     output_hidden_states=output_hidden_states,
#     936     return_dict=return_dict,
#     937     training=training,
#     938 )
#     940 sequence_output = encoder_outputs[0]
#     941 pooled_output = self.pooler(hidden_states=sequence_output) if self.pooler is not None else None
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:714, in TFXLMRobertaEncoder.call(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     710     all_hidden_states = all_hidden_states + (hidden_states,)
#     712 past_key_value = past_key_values[i] if past_key_values is not None else None
# --> 714 layer_outputs = layer_module(
#     715     hidden_states=hidden_states,
#     716     attention_mask=attention_mask,
#     717     head_mask=head_mask[i],
#     718     encoder_hidden_states=encoder_hidden_states,
#     719     encoder_attention_mask=encoder_attention_mask,
#     720     past_key_value=past_key_value,
#     721     output_attentions=output_attentions,
#     722     training=training,
#     723 )
#     724 hidden_states = layer_outputs[0]
#     726 if use_cache:
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:606, in TFXLMRobertaLayer.call(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     593 def call(
#     594     self,
#     595     hidden_states: tf.Tensor,
#    (...)
#     603 ) -> Tuple[tf.Tensor]:
#     604     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     605     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 606     self_attention_outputs = self.attention(
#     607         input_tensor=hidden_states,
#     608         attention_mask=attention_mask,
#     609         head_mask=head_mask,
#     610         encoder_hidden_states=None,
#     611         encoder_attention_mask=None,
#     612         past_key_value=self_attn_past_key_value,
#     613         output_attentions=output_attentions,
#     614         training=training,
#     615     )
#     616     attention_output = self_attention_outputs[0]
#     618     # if decoder, the last output is tuple of self-attn cache
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:497, in TFXLMRobertaAttention.call(self, input_tensor, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     476 def call(
#     477     self,
#     478     input_tensor: tf.Tensor,
#    (...)
#     485     training: bool = False,
#     486 ) -> Tuple[tf.Tensor]:
#     487     self_outputs = self.self_attention(
#     488         hidden_states=input_tensor,
#     489         attention_mask=attention_mask,
#    (...)
#     495         training=training,
#     496     )
# --> 497     attention_output = self.dense_output(
#     498         hidden_states=self_outputs[0], input_tensor=input_tensor, training=training
#     499     )
#     500     # add attentions (possibly with past_key_value) if we output them
#     501     outputs = (attention_output,) + self_outputs[1:]
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/transformers/models/xlm_roberta/modeling_tf_xlm_roberta.py:447, in TFXLMRobertaSelfOutput.call(self, hidden_states, input_tensor, training)
#     446 def call(self, hidden_states: tf.Tensor, input_tensor: tf.Tensor, training: bool = False) -> tf.Tensor:
# --> 447     hidden_states = self.dense(inputs=hidden_states)
#     448     hidden_states = self.dropout(inputs=hidden_states, training=training)
#     449     hidden_states = self.LayerNorm(inputs=hidden_states + input_tensor)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/keras/layers/core/dense.py:244, in Dense.call(self, inputs)
#     241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
# --> 244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#     245     # Reshape the output back to the original ndim of the input.
#     246     if not tf.executing_eagerly():
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py:5166, in tensordot(a, b, axes, name)
#    5164     return ab_matmul
#    5165   else:
# -> 5166     return array_ops.reshape(
#    5167         ab_matmul, a_free_dims + b_free_dims, name=name)
#    5168 else:
#    5169   a_free_dims = ops.convert_to_tensor(a_free_dims, dtype=dtypes.int32)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/ops/array_ops.py:196, in reshape(tensor, shape, name)
#      60 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      61 @dispatch.add_dispatch_support
#      62 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      63   r"""Reshapes a tensor.
#      64
#      65   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     194     A `Tensor`. Has the same type as `tensor`.
#     195   """
# --> 196   result = gen_array_ops.reshape(tensor, shape, name)
#     197   tensor_util.maybe_set_static_shape(result, shape)
#     198   return result
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/ops/gen_array_ops.py:8570, in reshape(tensor, shape, name)
#    8568   pass
#    8569 try:
# -> 8570   return reshape_eager_fallback(
#    8571       tensor, shape, name=name, ctx=_ctx)
#    8572 except _core._SymbolicException:
#    8573   pass  # Add nodes to the TensorFlow graph.
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/ops/gen_array_ops.py:8592, in reshape_eager_fallback(tensor, shape, name, ctx)
#    8590 def reshape_eager_fallback(tensor, shape, name, ctx):
#    8591   _attr_T, (tensor,) = _execute.args_to_matching_eager([tensor], ctx, [])
# -> 8592   _attr_Tshape, (shape,) = _execute.args_to_matching_eager([shape], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    8593   _inputs_flat = [tensor, shape]
#    8594   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:254, in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#     250 # First see if we can get a valid dtype with the default conversion
#     251 # and see if it matches an allowed dtypes. Some ops like ConcatV2 may
#     252 # not list allowed dtypes, in which case we should skip this.
#     253 if dtype is None and allowed_dtypes:
# --> 254   tensor = ops.convert_to_tensor(t, ctx=ctx)
#     255   # If we did not match an allowed dtype, try again with the default
#     256   # dtype. This could be because we have an empty tensor and thus we
#     257   # picked the wrong type.
#     258   if tensor.dtype not in allowed_dtypes:
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:1642, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1633       raise RuntimeError(
#    1634           _add_error_prefix(
#    1635               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1638               f"actual = {ret.dtype.base_dtype.name}",
#    1639               name=name))
#    1641 if ret is None:
# -> 1642   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1644 if ret is NotImplemented:
#    1645   continue
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:344, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     342                                          as_ref=False):
#     343   _ = as_ref
# --> 344   return constant(v, dtype=dtype, name=name)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:268, in constant(value, dtype, shape, name)
#     171 @tf_export("constant", v1=[])
#     172 def constant(value, dtype=None, shape=None, name="Const"):
#     173   """Creates a constant tensor from a tensor-like object.
#     174
#     175   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     266     ValueError: if called on a symbolic tensor.
#     267   """
# --> 268   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     269                         allow_broadcast=True)
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:280, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     278     with trace.Trace("tf.constant"):
#     279       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 280   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     282 g = ops.get_default_graph()
#     283 tensor_value = attr_value_pb2.AttrValue()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:305, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     303 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     304   """Creates a constant on the current device."""
# --> 305   t = convert_to_eager_tensor(value, ctx, dtype)
#     306   if shape is None:
#     307     return t
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:

# %%
# Out:
# (6815, 6)
