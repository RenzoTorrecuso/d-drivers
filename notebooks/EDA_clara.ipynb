# %%
import pandas as pd
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_colwidth', None)
pd.plotting.register_matplotlib_converters()
import pygwalker as pyg

import numpy as np
import seaborn as sns
import missingno as mgn

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import matplotlib.pyplot as plt

pio.templates.default = "simple_white"

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('/Users/clara/Desktop/neuefische/d-drivers/data/data_features.csv')
#df.drop([])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6815 entries, 0 to 6814
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   page_id                 6815 non-null   int64
#  1   n_days                  6815 non-null   int64
#  2   date_min                6815 non-null   object
#  3   n_urls                  6815 non-null   int64
#  4   date_max                6815 non-null   object
#  5   age                     6815 non-null   int64
#  6   url                     6815 non-null   object
#  7   no_versions             6815 non-null   int64
#  8   last_publish_date       6815 non-null   object
#  9   word_count              6815 non-null   float64
#  10  classification_product  6815 non-null   object
#  11  classification_type     6815 non-null   object
#  12  page_name               6815 non-null   object
#  13  title                   6815 non-null   object
#  14  author_list             6815 non-null   object
#  15  external_clicks         6815 non-null   float64
#  16  external_impressions    6815 non-null   float64
#  17  total_likes_n_days      6815 non-null   float64
#  18  daily_likes_median      6815 non-null   float64
#  19  total_dislikes_n_days   6815 non-null   float64
#  20  daily_dislikes_median   6815 non-null   float64
#  21  video_play              6815 non-null   float64
#  22  page_impressions        6815 non-null   float64
#  23  clickouts               6815 non-null   float64
#  24  ctr                     6815 non-null   float64
#  25  mean_version_lifetime   6815 non-null   float64
#  26  publ_freq               6815 non-null   float64
#  27  ext_impr_norm           6815 non-null   float64
#  28  urls_per_age            6815 non-null   float64
#  29  urls_per_days           6815 non-null   float64
#  30  h1                      6815 non-null   object
#  31  scraped_author          6815 non-null   object
#  32  date_scraped            6815 non-null   object
#  33  abstract                6808 non-null   object
#  34  scraped_word_count      6815 non-null   int64
#  35  meta_title              6815 non-null   object
#  36  meta_description        6815 non-null   object
#  37  meta_image_url          6815 non-null   object
#  38  media_type              6815 non-null   object
#  39  page_img_size           5066 non-null   object
#  40  merged_url              6815 non-null   object
#  41  meta_title_len          6815 non-null   int64
#  42  meta_desc_len           6815 non-null   int64
#  43  h1_len                  6815 non-null   int64
#  44  abstract_len            6808 non-null   float64
#  45  merged_url_len          6815 non-null   int64
#  46  title_has_colon         6815 non-null   bool
#  47  clickbait_prob          6815 non-null   float64
#  48  clickbait_label         6815 non-null   object
#  49  clickbait_prob_raw      6815 non-null   float64
#  50  google_trend_prob       6815 non-null   float64
#  51  google_trend_label      6815 non-null   object
#  52  google_trend_score      6815 non-null   int64
#  53  video_player_types      5824 non-null   object
# dtypes: bool(1), float64(20), int64(11), object(22)
# memory usage: 2.8+ MB

# %%
# Summarize all target variables in a list
target = ['crt', 'external_clicks', 'external_impressions']

# Summarize all numeric variables in a list
num_variables = df.select_dtypes(include=[np.number]).columns.tolist()
# columns_to_remove = ['external_clicks', 'external_impressions', 'ctr']
# for col in columns_to_remove:
#     num_variables.remove(col)

# %%
# Compute the correlation matrix
corr_matrix = df[num_variables].corr()

# Print the correlation matrix
print(corr_matrix)

# Create heatmap of correlation matrix
fig = px.imshow(corr_matrix, color_continuous_scale='RdBu', title='Correlation Matrix')
fig.show()
# Out:
#                         page_id    n_days    n_urls       age  no_versions
# page_id                1.000000 -0.300763 -0.227742 -0.175386    -0.166102  \
# n_days                -0.300763  1.000000  0.615208  0.041246     0.624605
# n_urls                -0.227742  0.615208  1.000000 -0.024247     0.929689
# age                   -0.175386  0.041246 -0.024247  1.000000     0.066423
# no_versions           -0.166102  0.624605  0.929689  0.066423     1.000000
# word_count            -0.086368  0.162702  0.185634 -0.313156     0.194164
# external_clicks        0.002478  0.238998  0.293525 -0.023107     0.289728
# external_impressions   0.001997  0.267615  0.324947 -0.028377     0.325063
# total_likes_n_days    -0.046476  0.104402  0.123044  0.012987     0.104666
# daily_likes_median     0.005696 -0.020508  0.013294  0.055474     0.012127
# total_dislikes_n_days -0.039736  0.054709  0.089376  0.004068     0.064199
# daily_dislikes_median  0.006544 -0.017823  0.003271  0.029164     0.001675
# video_play             0.006177  0.276891  0.313687 -0.035206     0.310418
# page_impressions       0.009198  0.309372  0.334653 -0.045051     0.337776
# clickouts             -0.058957  0.473494  0.494711 -0.009441     0.553721
# ctr                   -0.188644  0.080662 -0.004324  0.080295    -0.022170
# mean_version_lifetime -0.329287  0.507053  0.081738  0.031029     0.040493
# publ_freq             -0.001688 -0.146150 -0.069775  0.052640    -0.084455
# ext_impr_norm          0.038429  0.053936  0.115477  0.003058     0.108720
# urls_per_age          -0.073021  0.375463  0.648915 -0.366815     0.599627
# urls_per_days         -0.079355 -0.231622 -0.008643  0.047086    -0.064435
# scraped_word_count    -0.382895  0.317928  0.251357  0.026716     0.247983
# meta_title_len         0.128259 -0.085379 -0.133782  0.015657    -0.113786
# meta_desc_len          0.048708 -0.039672 -0.075214 -0.197312    -0.116230
# h1_len                 0.036908  0.006077  0.026831  0.019977     0.027622
# abstract_len          -0.082623  0.071993  0.084147 -0.026051     0.097986
# merged_url_len         0.003588 -0.021901 -0.045449  0.015586    -0.059106
# clickbait_prob        -0.023445  0.011830  0.002301  0.005761    -0.001948
# clickbait_prob_raw     0.023730 -0.012660  0.002749 -0.022974     0.005506
# google_trend_prob     -0.008381 -0.023619 -0.001948 -0.018957     0.005824
# google_trend_score    -0.073326  0.027853 -0.001782 -0.007365    -0.004975
#
#                        word_count  external_clicks  external_impressions
# page_id                 -0.086368         0.002478              0.001997  \
# n_days                   0.162702         0.238998              0.267615
# n_urls                   0.185634         0.293525              0.324947
# age                     -0.313156        -0.023107             -0.028377
# no_versions              0.194164         0.289728              0.325063
# word_count               1.000000         0.035535              0.044973
# external_clicks          0.035535         1.000000              0.989970
# external_impressions     0.044973         0.989970              1.000000
# total_likes_n_days       0.055622         0.412528              0.394297
# daily_likes_median       0.000679         0.152509              0.169138
# total_dislikes_n_days    0.039406         0.344655              0.308884
# daily_dislikes_median    0.011120         0.063732              0.068660
# video_play               0.047537         0.926818              0.923087
# page_impressions         0.057033         0.920344              0.918439
# clickouts                0.156360         0.116950              0.159428
# ctr                     -0.163384         0.069412              0.050389
# mean_version_lifetime    0.048592         0.038561              0.041459
# publ_freq               -0.117228        -0.044671             -0.049028
# ext_impr_norm            0.002535         0.510544              0.528522
# urls_per_age             0.193681         0.218811              0.244114
# urls_per_days           -0.096567        -0.041711             -0.046806
# scraped_word_count       0.631193        -0.004927              0.001695
# meta_title_len          -0.094299         0.015345              0.010097
# meta_desc_len           -0.020082        -0.058736             -0.063580
# h1_len                  -0.036092         0.017798              0.017813
# abstract_len             0.173824         0.018597              0.022194
# merged_url_len          -0.056029        -0.037516             -0.039153
# clickbait_prob           0.048090         0.014077              0.015477
# clickbait_prob_raw      -0.029076        -0.014883             -0.013421
# google_trend_prob        0.035167        -0.024011             -0.026452
# google_trend_score       0.013339        -0.028228             -0.026187
#
#                        total_likes_n_days  daily_likes_median  ...
# page_id                         -0.046476            0.005696  ...  \
# n_days                           0.104402           -0.020508  ...
# n_urls                           0.123044            0.013294  ...
# age                              0.012987            0.055474  ...
# no_versions                      0.104666            0.012127  ...
# word_count                       0.055622            0.000679  ...
# external_clicks                  0.412528            0.152509  ...
# external_impressions             0.394297            0.169138  ...
# total_likes_n_days               1.000000            0.063450  ...
# daily_likes_median               0.063450            1.000000  ...
# total_dislikes_n_days            0.943195            0.015510  ...
# daily_dislikes_median            0.030230            0.425584  ...
# video_play                       0.421122            0.131215  ...
# page_impressions                 0.380777            0.117421  ...
# clickouts                        0.073518           -0.006896  ...
# ctr                              0.023928            0.017716  ...
# mean_version_lifetime            0.013211           -0.026905  ...
# publ_freq                       -0.016819            0.033261  ...
# ext_impr_norm                    0.228530            0.791979  ...
# urls_per_age                     0.063130           -0.012352  ...
# urls_per_days                   -0.009603            0.099314  ...
# scraped_word_count               0.032529           -0.004746  ...
# meta_title_len                   0.010496           -0.005171  ...
# meta_desc_len                   -0.025262           -0.085756  ...
# h1_len                           0.014983           -0.005491  ...
# abstract_len                     0.014546           -0.008076  ...
# merged_url_len                  -0.009878           -0.015839  ...
# clickbait_prob                  -0.003308           -0.004348  ...
# clickbait_prob_raw               0.003744            0.001690  ...
# google_trend_prob               -0.012852            0.020887  ...
# google_trend_score              -0.014504           -0.010057  ...
#
#                        scraped_word_count  meta_title_len  meta_desc_len
# page_id                         -0.382895        0.128259       0.048708  \
# n_days                           0.317928       -0.085379      -0.039672
# n_urls                           0.251357       -0.133782      -0.075214
# age                              0.026716        0.015657      -0.197312
# no_versions                      0.247983       -0.113786      -0.116230
# word_count                       0.631193       -0.094299      -0.020082
# external_clicks                 -0.004927        0.015345      -0.058736
# external_impressions             0.001695        0.010097      -0.063580
# total_likes_n_days               0.032529        0.010496      -0.025262
# daily_likes_median              -0.004746       -0.005171      -0.085756
# total_dislikes_n_days            0.019701        0.012796      -0.008584
# daily_dislikes_median           -0.000073       -0.000889      -0.034526
# video_play                      -0.011218        0.021384      -0.050868
# page_impressions                -0.005248        0.016779      -0.048727
# clickouts                        0.181940       -0.059416      -0.027032
# ctr                             -0.017277        0.050522       0.046941
# mean_version_lifetime            0.252963       -0.044367       0.013804
# publ_freq                       -0.043911       -0.024418      -0.030627
# ext_impr_norm                   -0.045536        0.017881      -0.081569
# urls_per_age                     0.143035       -0.095789      -0.028961
# urls_per_days                   -0.008281       -0.041390      -0.067160
# scraped_word_count               1.000000       -0.162182      -0.093669
# meta_title_len                  -0.162182        1.000000       0.121648
# meta_desc_len                   -0.093669        0.121648       1.000000
# h1_len                          -0.033379        0.795216       0.033206
# abstract_len                     0.170543       -0.019156       0.009927
# merged_url_len                  -0.029420        0.463235       0.097060
# clickbait_prob                   0.011238       -0.144249      -0.014096
# clickbait_prob_raw               0.000428        0.140214       0.038342
# google_trend_prob                0.010543       -0.051101      -0.078589
# google_trend_score               0.039267       -0.037116       0.005780
#
#                          h1_len  abstract_len  merged_url_len  clickbait_prob
# page_id                0.036908     -0.082623        0.003588       -0.023445  \
# n_days                 0.006077      0.071993       -0.021901        0.011830
# n_urls                 0.026831      0.084147       -0.045449        0.002301
# age                    0.019977     -0.026051        0.015586        0.005761
# no_versions            0.027622      0.097986       -0.059106       -0.001948
# word_count            -0.036092      0.173824       -0.056029        0.048090
# external_clicks        0.017798      0.018597       -0.037516        0.014077
# external_impressions   0.017813      0.022194       -0.039153        0.015477
# total_likes_n_days     0.014983      0.014546       -0.009878       -0.003308
# daily_likes_median    -0.005491     -0.008076       -0.015839       -0.004348
# total_dislikes_n_days  0.012938      0.003850       -0.000560       -0.005869
# daily_dislikes_median -0.003163      0.004272       -0.007555       -0.008056
# video_play             0.025068      0.027665       -0.036238        0.022801
# page_impressions       0.022373      0.034281       -0.039163        0.020114
# clickouts              0.023072      0.060320       -0.018469       -0.025840
# ctr                    0.043659      0.005169        0.045501       -0.017868
# mean_version_lifetime -0.016918      0.027529        0.017663        0.029490
# publ_freq             -0.022425     -0.025035       -0.025879       -0.012089
# ext_impr_norm          0.012964      0.017784       -0.035674        0.004671
# urls_per_age           0.024743      0.066775       -0.042267        0.007631
# urls_per_days         -0.016168     -0.017179       -0.032664       -0.012526
# scraped_word_count    -0.033379      0.170543       -0.029420        0.011238
# meta_title_len         0.795216     -0.019156        0.463235       -0.144249
# meta_desc_len          0.033206      0.009927        0.097060       -0.014096
# h1_len                 1.000000      0.004531        0.444874       -0.174139
# abstract_len           0.004531      1.000000       -0.025121       -0.003709
# merged_url_len         0.444874     -0.025121        1.000000       -0.117429
# clickbait_prob        -0.174139     -0.003709       -0.117429        1.000000
# clickbait_prob_raw     0.179090      0.013415        0.164481       -0.646879
# google_trend_prob     -0.040528     -0.088943       -0.031175        0.036280
# google_trend_score    -0.031058      0.010175        0.033251        0.015958
#
#                        clickbait_prob_raw  google_trend_prob
# page_id                          0.023730          -0.008381  \
# n_days                          -0.012660          -0.023619
# n_urls                           0.002749          -0.001948
# age                             -0.022974          -0.018957
# no_versions                      0.005506           0.005824
# word_count                      -0.029076           0.035167
# external_clicks                 -0.014883          -0.024011
# external_impressions            -0.013421          -0.026452
# total_likes_n_days               0.003744          -0.012852
# daily_likes_median               0.001690           0.020887
# total_dislikes_n_days            0.006322          -0.008910
# daily_dislikes_median            0.008852          -0.000880
# video_play                      -0.019534          -0.030379
# page_impressions                -0.014186          -0.033341
# clickouts                        0.026686          -0.036872
# ctr                              0.014344          -0.034444
# mean_version_lifetime           -0.018002          -0.007096
# publ_freq                        0.014619          -0.013033
# ext_impr_norm                   -0.001888          -0.004685
# urls_per_age                     0.003612          -0.014282
# urls_per_days                    0.006846           0.003328
# scraped_word_count               0.000428           0.010543
# meta_title_len                   0.140214          -0.051101
# meta_desc_len                    0.038342          -0.078589
# h1_len                           0.179090          -0.040528
# abstract_len                     0.013415          -0.088943
# merged_url_len                   0.164481          -0.031175
# clickbait_prob                  -0.646879           0.036280
# clickbait_prob_raw               1.000000          -0.049926
# google_trend_prob               -0.049926           1.000000
# google_trend_score              -0.029785           0.175525
#
#                        google_trend_score
# page_id                         -0.073326
# n_days                           0.027853
# n_urls                          -0.001782
# age                             -0.007365
# no_versions                     -0.004975
# word_count                       0.013339
# external_clicks                 -0.028228
# external_impressions            -0.026187
# total_likes_n_days              -0.014504
# daily_likes_median              -0.010057
# total_dislikes_n_days           -0.017999
# daily_dislikes_median           -0.015913
# video_play                      -0.033068
# page_impressions                -0.031192
# clickouts                       -0.014293
# ctr                             -0.018437
# mean_version_lifetime            0.078765
# publ_freq                       -0.011302
# ext_impr_norm                   -0.025156
# urls_per_age                    -0.012791
# urls_per_days                   -0.008400
# scraped_word_count               0.039267
# meta_title_len                  -0.037116
# meta_desc_len                    0.005780
# h1_len                          -0.031058
# abstract_len                     0.010175
# merged_url_len                   0.033251
# clickbait_prob                   0.015958
# clickbait_prob_raw              -0.029785
# google_trend_prob                0.175525
# google_trend_score               1.000000
#
# [31 rows x 31 columns]

# %%
# Compute the correlation matrix
corr_matrix = df[num_variables].corr()

# Set the threshold for significant correlations
threshold = 0.5  # You can adjust this threshold as needed

# Create a mask to filter out insignificant correlations
mask = np.abs(corr_matrix) >= threshold
corr_matrix_filtered = corr_matrix[mask]

# Print the filtered correlation matrix
print(corr_matrix_filtered)

# Create heatmap of filtered correlation matrix
fig = px.imshow(corr_matrix_filtered, color_continuous_scale='RdBu', title='Significant Correlations (absolute value >= 0.5)')
fig.show()
# Out:
#                        page_id    n_days    n_urls  age  no_versions
# page_id                    1.0       NaN       NaN  NaN          NaN  \
# n_days                     NaN  1.000000  0.615208  NaN     0.624605
# n_urls                     NaN  0.615208  1.000000  NaN     0.929689
# age                        NaN       NaN       NaN  1.0          NaN
# no_versions                NaN  0.624605  0.929689  NaN     1.000000
# word_count                 NaN       NaN       NaN  NaN          NaN
# external_clicks            NaN       NaN       NaN  NaN          NaN
# external_impressions       NaN       NaN       NaN  NaN          NaN
# total_likes_n_days         NaN       NaN       NaN  NaN          NaN
# daily_likes_median         NaN       NaN       NaN  NaN          NaN
# total_dislikes_n_days      NaN       NaN       NaN  NaN          NaN
# daily_dislikes_median      NaN       NaN       NaN  NaN          NaN
# video_play                 NaN       NaN       NaN  NaN          NaN
# page_impressions           NaN       NaN       NaN  NaN          NaN
# clickouts                  NaN       NaN       NaN  NaN     0.553721
# ctr                        NaN       NaN       NaN  NaN          NaN
# mean_version_lifetime      NaN  0.507053       NaN  NaN          NaN
# publ_freq                  NaN       NaN       NaN  NaN          NaN
# ext_impr_norm              NaN       NaN       NaN  NaN          NaN
# urls_per_age               NaN       NaN  0.648915  NaN     0.599627
# urls_per_days              NaN       NaN       NaN  NaN          NaN
# scraped_word_count         NaN       NaN       NaN  NaN          NaN
# meta_title_len             NaN       NaN       NaN  NaN          NaN
# meta_desc_len              NaN       NaN       NaN  NaN          NaN
# h1_len                     NaN       NaN       NaN  NaN          NaN
# abstract_len               NaN       NaN       NaN  NaN          NaN
# merged_url_len             NaN       NaN       NaN  NaN          NaN
# clickbait_prob             NaN       NaN       NaN  NaN          NaN
# clickbait_prob_raw         NaN       NaN       NaN  NaN          NaN
# google_trend_prob          NaN       NaN       NaN  NaN          NaN
# google_trend_score         NaN       NaN       NaN  NaN          NaN
#
#                        word_count  external_clicks  external_impressions
# page_id                       NaN              NaN                   NaN  \
# n_days                        NaN              NaN                   NaN
# n_urls                        NaN              NaN                   NaN
# age                           NaN              NaN                   NaN
# no_versions                   NaN              NaN                   NaN
# word_count               1.000000              NaN                   NaN
# external_clicks               NaN         1.000000              0.989970
# external_impressions          NaN         0.989970              1.000000
# total_likes_n_days            NaN              NaN                   NaN
# daily_likes_median            NaN              NaN                   NaN
# total_dislikes_n_days         NaN              NaN                   NaN
# daily_dislikes_median         NaN              NaN                   NaN
# video_play                    NaN         0.926818              0.923087
# page_impressions              NaN         0.920344              0.918439
# clickouts                     NaN              NaN                   NaN
# ctr                           NaN              NaN                   NaN
# mean_version_lifetime         NaN              NaN                   NaN
# publ_freq                     NaN              NaN                   NaN
# ext_impr_norm                 NaN         0.510544              0.528522
# urls_per_age                  NaN              NaN                   NaN
# urls_per_days                 NaN              NaN                   NaN
# scraped_word_count       0.631193              NaN                   NaN
# meta_title_len                NaN              NaN                   NaN
# meta_desc_len                 NaN              NaN                   NaN
# h1_len                        NaN              NaN                   NaN
# abstract_len                  NaN              NaN                   NaN
# merged_url_len                NaN              NaN                   NaN
# clickbait_prob                NaN              NaN                   NaN
# clickbait_prob_raw            NaN              NaN                   NaN
# google_trend_prob             NaN              NaN                   NaN
# google_trend_score            NaN              NaN                   NaN
#
#                        total_likes_n_days  daily_likes_median  ...
# page_id                               NaN                 NaN  ...  \
# n_days                                NaN                 NaN  ...
# n_urls                                NaN                 NaN  ...
# age                                   NaN                 NaN  ...
# no_versions                           NaN                 NaN  ...
# word_count                            NaN                 NaN  ...
# external_clicks                       NaN                 NaN  ...
# external_impressions                  NaN                 NaN  ...
# total_likes_n_days               1.000000                 NaN  ...
# daily_likes_median                    NaN            1.000000  ...
# total_dislikes_n_days            0.943195                 NaN  ...
# daily_dislikes_median                 NaN                 NaN  ...
# video_play                            NaN                 NaN  ...
# page_impressions                      NaN                 NaN  ...
# clickouts                             NaN                 NaN  ...
# ctr                                   NaN                 NaN  ...
# mean_version_lifetime                 NaN                 NaN  ...
# publ_freq                             NaN                 NaN  ...
# ext_impr_norm                         NaN            0.791979  ...
# urls_per_age                          NaN                 NaN  ...
# urls_per_days                         NaN                 NaN  ...
# scraped_word_count                    NaN                 NaN  ...
# meta_title_len                        NaN                 NaN  ...
# meta_desc_len                         NaN                 NaN  ...
# h1_len                                NaN                 NaN  ...
# abstract_len                          NaN                 NaN  ...
# merged_url_len                        NaN                 NaN  ...
# clickbait_prob                        NaN                 NaN  ...
# clickbait_prob_raw                    NaN                 NaN  ...
# google_trend_prob                     NaN                 NaN  ...
# google_trend_score                    NaN                 NaN  ...
#
#                        scraped_word_count  meta_title_len  meta_desc_len
# page_id                               NaN             NaN            NaN  \
# n_days                                NaN             NaN            NaN
# n_urls                                NaN             NaN            NaN
# age                                   NaN             NaN            NaN
# no_versions                           NaN             NaN            NaN
# word_count                       0.631193             NaN            NaN
# external_clicks                       NaN             NaN            NaN
# external_impressions                  NaN             NaN            NaN
# total_likes_n_days                    NaN             NaN            NaN
# daily_likes_median                    NaN             NaN            NaN
# total_dislikes_n_days                 NaN             NaN            NaN
# daily_dislikes_median                 NaN             NaN            NaN
# video_play                            NaN             NaN            NaN
# page_impressions                      NaN             NaN            NaN
# clickouts                             NaN             NaN            NaN
# ctr                                   NaN             NaN            NaN
# mean_version_lifetime                 NaN             NaN            NaN
# publ_freq                             NaN             NaN            NaN
# ext_impr_norm                         NaN             NaN            NaN
# urls_per_age                          NaN             NaN            NaN
# urls_per_days                         NaN             NaN            NaN
# scraped_word_count               1.000000             NaN            NaN
# meta_title_len                        NaN        1.000000            NaN
# meta_desc_len                         NaN             NaN            1.0
# h1_len                                NaN        0.795216            NaN
# abstract_len                          NaN             NaN            NaN
# merged_url_len                        NaN             NaN            NaN
# clickbait_prob                        NaN             NaN            NaN
# clickbait_prob_raw                    NaN             NaN            NaN
# google_trend_prob                     NaN             NaN            NaN
# google_trend_score                    NaN             NaN            NaN
#
#                          h1_len  abstract_len  merged_url_len  clickbait_prob
# page_id                     NaN           NaN             NaN             NaN  \
# n_days                      NaN           NaN             NaN             NaN
# n_urls                      NaN           NaN             NaN             NaN
# age                         NaN           NaN             NaN             NaN
# no_versions                 NaN           NaN             NaN             NaN
# word_count                  NaN           NaN             NaN             NaN
# external_clicks             NaN           NaN             NaN             NaN
# external_impressions        NaN           NaN             NaN             NaN
# total_likes_n_days          NaN           NaN             NaN             NaN
# daily_likes_median          NaN           NaN             NaN             NaN
# total_dislikes_n_days       NaN           NaN             NaN             NaN
# daily_dislikes_median       NaN           NaN             NaN             NaN
# video_play                  NaN           NaN             NaN             NaN
# page_impressions            NaN           NaN             NaN             NaN
# clickouts                   NaN           NaN             NaN             NaN
# ctr                         NaN           NaN             NaN             NaN
# mean_version_lifetime       NaN           NaN             NaN             NaN
# publ_freq                   NaN           NaN             NaN             NaN
# ext_impr_norm               NaN           NaN             NaN             NaN
# urls_per_age                NaN           NaN             NaN             NaN
# urls_per_days               NaN           NaN             NaN             NaN
# scraped_word_count          NaN           NaN             NaN             NaN
# meta_title_len         0.795216           NaN             NaN             NaN
# meta_desc_len               NaN           NaN             NaN             NaN
# h1_len                 1.000000           NaN             NaN             NaN
# abstract_len                NaN           1.0             NaN             NaN
# merged_url_len              NaN           NaN             1.0             NaN
# clickbait_prob              NaN           NaN             NaN        1.000000
# clickbait_prob_raw          NaN           NaN             NaN       -0.646879
# google_trend_prob           NaN           NaN             NaN             NaN
# google_trend_score          NaN           NaN             NaN             NaN
#
#                        clickbait_prob_raw  google_trend_prob
# page_id                               NaN                NaN  \
# n_days                                NaN                NaN
# n_urls                                NaN                NaN
# age                                   NaN                NaN
# no_versions                           NaN                NaN
# word_count                            NaN                NaN
# external_clicks                       NaN                NaN
# external_impressions                  NaN                NaN
# total_likes_n_days                    NaN                NaN
# daily_likes_median                    NaN                NaN
# total_dislikes_n_days                 NaN                NaN
# daily_dislikes_median                 NaN                NaN
# video_play                            NaN                NaN
# page_impressions                      NaN                NaN
# clickouts                             NaN                NaN
# ctr                                   NaN                NaN
# mean_version_lifetime                 NaN                NaN
# publ_freq                             NaN                NaN
# ext_impr_norm                         NaN                NaN
# urls_per_age                          NaN                NaN
# urls_per_days                         NaN                NaN
# scraped_word_count                    NaN                NaN
# meta_title_len                        NaN                NaN
# meta_desc_len                         NaN                NaN
# h1_len                                NaN                NaN
# abstract_len                          NaN                NaN
# merged_url_len                        NaN                NaN
# clickbait_prob                  -0.646879                NaN
# clickbait_prob_raw               1.000000                NaN
# google_trend_prob                     NaN                1.0
# google_trend_score                    NaN                NaN
#
#                        google_trend_score
# page_id                               NaN
# n_days                                NaN
# n_urls                                NaN
# age                                   NaN
# no_versions                           NaN
# word_count                            NaN
# external_clicks                       NaN
# external_impressions                  NaN
# total_likes_n_days                    NaN
# daily_likes_median                    NaN
# total_dislikes_n_days                 NaN
# daily_dislikes_median                 NaN
# video_play                            NaN
# page_impressions                      NaN
# clickouts                             NaN
# ctr                                   NaN
# mean_version_lifetime                 NaN
# publ_freq                             NaN
# ext_impr_norm                         NaN
# urls_per_age                          NaN
# urls_per_days                         NaN
# scraped_word_count                    NaN
# meta_title_len                        NaN
# meta_desc_len                         NaN
# h1_len                                NaN
# abstract_len                          NaN
# merged_url_len                        NaN
# clickbait_prob                        NaN
# clickbait_prob_raw                    NaN
# google_trend_prob                     NaN
# google_trend_score                    1.0
#
# [31 rows x 31 columns]

# %%
df.classification_product.unique()
# Out:
# array(['E-Auto', 'Auto', 'Zubehör', 'Motorrad', 'Energie', 'Verkehr',
#        'Wallbox/Laden', 'Solaranlagen', 'E-Bike', 'Fahrrad', 'E-Scooter',
#        'Solarspeicher', 'Balkonkraftwerk', 'Solargenerator', 'THG',
#        'Wärmepumpe', 'Versicherung'], dtype=object)

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0006164bee28002dTyI7kA2JpPZxQlzw" style="height: auto">\n    <head>…
