# %%
import pandas as pd
import pygwalker as pyg

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_colwidth', None)
pd.plotting.register_matplotlib_converters()

import numpy as np
import seaborn as sns
import missingno as mgn
import matplotlib as plt
import plotly.express as px

# %%
df = pd.read_csv('../data/unique_IDs_merged.csv')

# %%
df['date'] = pd.to_datetime(df['date'])
df['publish_date'] = pd.to_datetime(df['publish_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6899 entries, 0 to 6898
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   page_id                 6899 non-null   int64
#  1   date                    6899 non-null   datetime64[ns]
#  2   publish_date            4580 non-null   datetime64[ns]
#  3   title                   6899 non-null   object
#  4   h1                      5814 non-null   object
#  5   abstract                5814 non-null   object
#  6   classification_product  6864 non-null   object
#  7   classification_type     6864 non-null   object
#  8   authors                 6899 non-null   object
#  9   word_count              4551 non-null   float64
#  10  image_url               5814 non-null   object
#  11  daily_likes             1629 non-null   float64
#  12  daily_dislikes          1005 non-null   float64
#  13  video_play              6847 non-null   float64
#  14  page_impressions        6847 non-null   float64
#  15  clickouts               5170 non-null   float64
#  16  external_clicks         6847 non-null   float64
#  17  external_impressions    6847 non-null   float64
#  18  ctr                     6847 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(7)
# memory usage: 1.0+ MB

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0006150bc80fa4b0grw9oE3BMRJafiqh" style="height: auto">\n    <head>…

# %%
df.head()
# Out:
#    page_id       date publish_date
# 0     1037 2024-03-13   2024-03-10  \
# 1     1039 2024-03-17   2022-05-05
# 2     1040 2024-02-22   2024-02-21
# 3    10245 2023-03-25          NaT
# 4    10273 2023-12-01          NaT
#
#                                                title
# 0                     Ladestationen für Elektroautos  \
# 1   Elektroauto-Förderung 2022: Hier können Sie n...
# 2   Geschichte der Elektroautos: Erste Stromer de...
# 3   Das kleinste Auto der Welt – jetzt auch als E...
# 4   So fahren E-Autos im Winter weiter: Diese 6 T...
#
#                                                   h1
# 0                                                NaN  \
# 1                                                NaN
# 2  Hätten Sie es gewusst? So lange gibt es schon ...
# 3  Kleinstes Auto der Welt kommt zurück: Fans kön...
# 4                                                NaN
#
#                                             abstract classification_product
# 0                                                NaN                 E-Auto  \
# 1                                                NaN                 E-Auto
# 2  Noch vor wenigen Jahren wurden Elektroautos al...                 E-Auto
# 3  Der P.50, auch bekannt als das kleinste Auto d...                   Auto
# 4                                                NaN                 E-Auto
#
#   classification_type            authors  word_count
# 0            Ratgeber     Eva Goldschald       827.0  \
# 1                News    Moritz Diethelm      1066.0
# 2                News  Marius Eichfelder       466.0
# 3        Kaufberatung        Sven Schulz         NaN
# 4            Ratgeber    Sepp Reitberger         NaN
#
#                                            image_url  daily_likes
# 0                                                NaN          0.0  \
# 1                                                NaN          0.0
# 2  https://im-efahrer.chip.de/files/600ea8e731452...          1.0
# 3  https://im-efahrer.chip.de/files/kleinsteautod...          NaN
# 4                                                NaN          NaN
#
#    daily_dislikes  video_play  page_impressions  clickouts  external_clicks
# 0             0.0         0.0              15.0        0.0             22.0  \
# 1             0.0         3.0               3.0        0.0             62.0
# 2             0.0        19.0              56.0        0.0              6.0
# 3             NaN        41.0              63.0        0.0             19.0
# 4             NaN       608.0             452.0        1.0             82.0
#
#    external_impressions       ctr
# 0                 343.0  6.413994
# 1                 864.0  7.175926
# 2                 260.0  2.307692
# 3                 215.0  8.837209
# 4                2983.0  2.748910

# %%
# Summarize all target variables in a list
target = ['crt', 'external_clicks', 'external_impressions']

# Summarize all numeric variables in a list
num_variables = df.select_dtypes(include=[np.number]).columns.tolist()
columns_to_remove = ['external_clicks', 'external_impressions', 'ctr']
for col in columns_to_remove:
    num_variables.remove(col)

# %% [markdown]
# Some basic plots for EDA

# %%
# Histogram of word count
fig1 = px.histogram(df, x='word_count', title='Distribution of Word Count')

# Scatter plot of word count vs. CTR
fig2 = px.scatter(df, x='word_count', y='ctr', title='Word Count vs. CTR')

# Box plot of CTR by classification_product
fig3 = px.box(df, x='classification_product', y='ctr', title='CTR by Product Classification')

# Scatter plot of external clicks vs. external impressions
fig4 = px.scatter(df, x='external_clicks', y='external_impressions', title='External Clicks vs. External Impressions')

# Display plots
fig1.show()
fig2.show()
fig3.show()
fig4.show()

# %%
# Compute the correlation matrix
corr_matrix = df[num_variables].corr()

# Print the correlation matrix
print(corr_matrix)

# Create heatmap of correlation matrix
fig = px.imshow(corr_matrix, color_continuous_scale='RdBu', title='Correlation Matrix')
fig.show()
# Out:
#                    page_id  word_count  daily_likes  daily_dislikes
# page_id           1.000000   -0.274209    -0.103181       -0.037845  \
# word_count       -0.274209    1.000000     0.080526        0.035122
# daily_likes      -0.103181    0.080526     1.000000        0.666727
# daily_dislikes   -0.037845    0.035122     0.666727        1.000000
# video_play        0.071787   -0.028526     0.115557        0.066809
# page_impressions  0.085632   -0.042384     0.111292        0.080225
# clickouts         0.026533    0.084486     0.008697        0.000785
# year              0.108222    0.045198    -0.053648       -0.050099
#
#                   video_play  page_impressions  clickouts      year
# page_id             0.071787          0.085632   0.026533  0.108222
# word_count         -0.028526         -0.042384   0.084486  0.045198
# daily_likes         0.115557          0.111292   0.008697 -0.053648
# daily_dislikes      0.066809          0.080225   0.000785 -0.050099
# video_play          1.000000          0.938665   0.087703 -0.039487
# page_impressions    0.938665          1.000000   0.130743 -0.054705
# clickouts           0.087703          0.130743   1.000000 -0.021359
# year               -0.039487         -0.054705  -0.021359  1.000000
